# %%
pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      --------------------------------------- 1.3/455.4 MB 11.1 MB/s eta 0:00:41
#      --------------------------------------- 5.5/455.4 MB 16.2 MB/s eta 0:00:28
#       ------------------------------------- 10.0/455.4 MB 18.7 MB/s eta 0:00:24
#      - ------------------------------------ 18.1/455.4 MB 24.4 MB/s eta 0:00:18
#      -- ----------------------------------- 25.7/455.4 MB 27.2 MB/s eta 0:00:16
#      -- ----------------------------------- 33.8/455.4 MB 29.4 MB/s eta 0:00:15
#      --- ---------------------------------- 43.3/455.4 MB 32.1 MB/s eta 0:00:13
#      ---- --------------------------------- 51.4/455.4 MB 33.8 MB/s eta 0:00:12
#      ----- -------------------------------- 61.1/455.4 MB 34.8 MB/s eta 0:00:12
#      ------ ------------------------------- 72.1/455.4 MB 36.6 MB/s eta 0:00:11
#      ------ ------------------------------- 82.8/455.4 MB 38.1 MB/s eta 0:00:10
# ...

# %%
from accelerators.databricks.accelerator import main
from pyspark.sql import SparkSession

main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from accelerators.databricks.accelerator import main
#       2 from pyspark.sql import SparkSession
#       4 main()
#
# ModuleNotFoundError: No module named 'accelerators'
