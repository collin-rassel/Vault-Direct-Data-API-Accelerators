# %%
pip install pyspark
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydantic
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyrfc6266
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azure-common
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azure-identity
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azure-storage-blob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import IPython
# IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
from accelerators.databricks.accelerator import main

main()
# Out:
# [Info] 2026-02-16 11:45:46 - Stop time dynamic date: 2026-02-16T00:00Z
# [Debug] 2026-02-16 11:45:46 - Listing Direct Data files with start time: 2000-01-01T00:00Z and stop time: 2026-02-16T00:00Z
# [Info] 2026-02-16 11:45:47 - Direct Data files listed successfully
# [Info] 2026-02-16 11:45:47 - File name determined for direct data extract: 56480-20260216-0000-F.tar.gz

# %% [markdown]
# ## Notes
# Need to add functionality to dynamically update the Azure filepath and extract folder based on the file names, currently have to manually enter that data
