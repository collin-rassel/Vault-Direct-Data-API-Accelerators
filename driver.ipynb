# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (4.1.1)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (23.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydantic
# Out:
# Requirement already satisfied: pydantic in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyrfc6266
# Out:
# Requirement already satisfied: pyrfc6266 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.0.2)
# Requirement already satisfied: pyparsing~=3.0.7 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pyrfc6266) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azure-common
# Out:
# Requirement already satisfied: azure-common in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.1.28)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azure-identity
# Out:
# Requirement already satisfied: azure-identity in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.25.2)
# Requirement already satisfied: azure-core>=1.31.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-identity) (1.38.1)
# Requirement already satisfied: cryptography>=2.5 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-identity) (46.0.4)
# Requirement already satisfied: msal>=1.31.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-identity) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azure-storage-blob
# Out:
# Requirement already satisfied: azure-storage-blob in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (12.28.0)
# Requirement already satisfied: azure-core>=1.30.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-storage-blob) (1.38.1)
# Requirement already satisfied: cryptography>=2.1.4 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-storage-blob) (46.0.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-storage-blob) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# Failed to read module file 'c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\urllib\parse.py' for module 'urllib.parse': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1398, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1371, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1335, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 2031: character maps to <undefined>
# Failed to read module file 'c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\re\_casefix.py' for module 're._casefix': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1398, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1371, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1335, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 911: character maps to <undefined>
# Failed to read module file 'c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\_strptime.py' for module '_strptime': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1398, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1371, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1335, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 1599: character maps to <undefined>
# Failed to read module file 'c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\functools.py' for module 'functools': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1398, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1371, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1335, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 308: character maps to <undefined>
# Failed to read module file 'c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\pydoc_data\topics.py' for module 'pydoc_data.topics': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1398, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1371, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1335, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 3098: character maps to <undefined>
# Failed to read module file 'c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\shlex.py' for module 'shlex': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1398, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1371, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1335, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\02713524\AppData\Roaming\Python\Python314\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1503: character maps to <undefined>

# %%
import os 
os._exit(00)

# %%
from accelerators.databricks.accelerator import main

main()
# Out:
# [Info] 2026-02-11 11:21:39 - ---Executing direct_data_to_object_storage.py---
# [Debug] 2026-02-11 11:21:39 - Listing Direct Data files with start time: 2000-01-01T00:00Z and stop time: 2026-02-11T00:00Z
# [Info] 2026-02-11 11:21:40 - Direct Data files listed successfully
# [Debug] 2026-02-11 11:21:40 - Downloading Direct Data file: 56480-20260211-0000-F.001
# [Info] 2026-02-11 11:21:43 - Direct Data file: 56480-20260211-0000-F.001 downloaded successfully
# [Debug] 2026-02-11 11:21:43 - Uploading to veeva-vault/direct-data/56480-20260211-0000-F.tar.gz
# [Debug] 2026-02-11 11:21:43 - Retrieving Blob Client for veeva-vault/direct-data/56480-20260211-0000-F.tar.gz
# [Info] 2026-02-11 11:21:43 - Retrieved Blob Client for veeva-vault/direct-data/56480-20260211-0000-F.tar.gz
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\storage\blob\_shared\policies.py:566, in StorageRetryPolicy.send(self, request)
#     565 try:
# --> 566     response = self.next.send(request)
#     567     if is_retry(response, retry_settings["mode"]) or is_checksum_retry(response):
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:159, in BearerTokenCredentialPolicy.send(self, request)
#     152 """Authorize request with a bearer token and send it to the next policy
#     153
#     154 :param request: The pipeline request object
#    (...)    157 :rtype: ~azure.core.pipeline.PipelineResponse
#     158 """
# --> 159 self.on_request(request)
#     160 try:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:134, in BearerTokenCredentialPolicy.on_request(self, request)
#     133 if self._token is None or self._need_new_token:
# --> 134     self._request_token(*self._scopes)
#     135 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:110, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     104 """Request a new token from the credential.
#     105
#     106 This will call the credential's appropriate method to get a token and store it in the policy.
#     107
#     108 :param str scopes: The type of access needed.
#     109 """
# --> 110 self._token = self._get_token(*scopes, **kwargs)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:100, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      98             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# --> 100     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#     101 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\identity\_credentials\default.py:376, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     375 try:
# --> 376     token_info = cast(SupportsTokenInfo, super()).get_token_info(*scopes, options=options)
#     377 finally:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\identity\_credentials\chained.py:225, in ChainedTokenCredential.get_token_info(self, options, *scopes)
#     224 _LOGGER.warning(message)
# --> 225 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 from accelerators.databricks.accelerator import main
# ----> 3 main()
#
# File c:\Repos\Vault-Direct-Data-API-Accelerators\accelerators\databricks\accelerator.py:37, in main()
#      34 #databricks_service: DatabricksService = DatabricksService(databricks_params)
#      35 vault_service: VaultService = VaultService(vapil_settings_filepath)
# ---> 37 direct_data_to_object_storage.run(vault_service=vault_service,
#      38                                   object_storage_service=blob_service,
#      39                                   direct_data_params=direct_data_params)
#
# File c:\Repos\Vault-Direct-Data-API-Accelerators\common\scripts\direct_data_to_object_storage.py:87, in run(vault_service, object_storage_service, direct_data_params)
#      82 if direct_data_item.fileparts == 1:
#      84     download_response: VaultResponse = vault_service.download_direct_data_file(
#      85         name=direct_data_item.filepart_details[0].name)
# ---> 87     object_storage_service.upload_object(
#      88         object_path=object_path,
#      89         data=io.BytesIO(download_response.binary_content)
#      90     )
#      92 # Create multi-part upload if Direct Data File has multiple parts
#      93 else:
#      94     _handle_multipart_upload(object_storage_service=object_storage_service,
#      95                              vault_service=vault_service,
#      96                              direct_data_item=direct_data_item,
#      97                              object_path=object_path)
#
# File c:\Repos\Vault-Direct-Data-API-Accelerators\common\services\azure_blob_service.py:88, in AzureBlobService.upload_object(self, object_path, data)
#      86 try:
#      87     blob_client: BlobClient = self.get_blob_client(blob_name=object_path)
# ---> 88     response: dict = blob_client.upload_blob(data=data, overwrite=True)
#      89     log_message(log_level='Info',
#      90                 message=f'Uploaded successfully to {self.container}/{blob_client.blob_name}')
#      91     return response
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\tracing\decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\storage\blob\_blob_client.py:631, in BlobClient.upload_blob(self, data, blob_type, length, metadata, **kwargs)
#     615 options = _upload_blob_options(
#     616     data=data,
#     617     blob_type=blob_type,
#    (...)    628     client=self._client,
#     629     **kwargs)
#     630 if blob_type == BlobType.BlockBlob:
# --> 631     return upload_block_blob(**options)
#     632 if blob_type == BlobType.PageBlob:
#     633     return upload_page_blob(**options)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\storage\blob\_upload_helpers.py:105, in upload_block_blob(client, stream, overwrite, encryption_options, blob_settings, headers, validate_content, max_concurrency, length, **kwargs)
#     102     encryption_data, data = encrypt_blob(data, encryption_options['key'], encryption_options['version'])
#     103     headers['x-ms-meta-encryptiondata'] = encryption_data
# --> 105 response = client.upload(
#     106     body=data,  # type: ignore [arg-type]
#     107     content_length=adjusted_count,
#     108     blob_http_headers=blob_headers,
#     109     headers=headers,
#     110     cls=return_response_headers,
#     111     validate_content=validate_content,
#     112     data_stream_total=adjusted_count,
#     113     upload_stream_current=0,
#     114     tier=tier.value if tier else None,
#     115     blob_tags_string=blob_tags_string,
#     116     immutability_policy_expiry=immutability_policy_expiry,
#     117     immutability_policy_mode=immutability_policy_mode,
#     118     legal_hold=legal_hold,
#     119     **kwargs)
#     121 if progress_hook:
#     122     progress_hook(adjusted_count, adjusted_count)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\tracing\decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\storage\blob\_generated\operations\_block_blob_operations.py:879, in BlockBlobOperations.upload(self, content_length, body, timeout, transactional_content_md5, metadata, tier, request_id_parameter, blob_tags_string, immutability_policy_expiry, immutability_policy_mode, legal_hold, transactional_content_crc64, structured_body_type, structured_content_length, blob_http_headers, lease_access_conditions, cpk_info, cpk_scope_info, modified_access_conditions, **kwargs)
#     876 _request.url = self._client.format_url(_request.url)
#     878 _stream = False
# --> 879 pipeline_response: PipelineResponse = self._client._pipeline.run(  # pylint: disable=protected-access
#     880     _request, stream=_stream, **kwargs
#     881 )
#     883 response = pipeline_response.http_response
#     885 if response.status_code not in [201]:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\policies\_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\storage\blob\_shared\policies.py:584, in StorageRetryPolicy.send(self, request)
#     582 if retries_remaining:
#     583     retry_hook(retry_settings, request=request.http_request, response=None, error=err)
# --> 584     self.sleep(retry_settings, request.context.transport)
#     585     continue
#     586 raise err
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\storage\blob\_shared\policies.py:491, in StorageRetryPolicy.sleep(self, settings, transport)
#     489 if not backoff or backoff < 0:
#     490     return
# --> 491 transport.sleep(backoff)
#
# File c:\Users\02713524\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\azure\core\pipeline\transport\_base.py:178, in HttpTransport.sleep(self, duration)
#     166 def sleep(self, duration: float) -> None:
#     167     """Sleep for the specified duration.
#     168
#     169     You should always ask the transport to sleep, and not call directly
#    (...)    176     :param float duration: The number of seconds to sleep.
#     177     """
# --> 178     time.sleep(duration)
#
# KeyboardInterrupt:
